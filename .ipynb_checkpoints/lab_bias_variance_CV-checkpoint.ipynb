# %% [markdown]
# #Bias, Variance, and Cross Validation

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
 
pd.options.display.max_columns = 10 
pd.options.display.width = 134
pd.options.display.max_rows = 20
 
rcParams['figure.figsize'] = (10, 6)
plt.style.use('bmh')
colors = ["#348ABD", "#A60628", "#7A68A6", "#467821", "#CF4457", "#188487", "#E24A33"]

import brewer2mpl
#colorbrewer2 Dark2 qualitative color table
dark2_cmap = brewer2mpl.get_map('Dark2', 'Qualitative', 7)
dark2_colors = dark2_cmap.mpl_colors

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
import random
import copy
def scatter_by(df, scatterx, scattery, by=None, figure=None, axes=None, colorscale=dark2_cmap, labeler={}, mfunc=None, setupfunc=None, mms=8):
    cs=copy.deepcopy(colorscale.mpl_colors)
    if not figure:
        figure=plt.figure(figsize=(8,8))
    if not axes:
        axes=figure.gca()
    x=df[scatterx]
    y=df[scattery]
    if not by:
        col=random.choice(cs)
        axes.scatter(x, y, cmap=colorscale, c=col)
        if setupfunc:
            axeslist=setupfunc(axes, figure)
        else:
            axeslist=[axes]
        if mfunc:
            mfunc(axeslist,x,y,color=col, mms=mms)
    else:
        cs=list(np.linspace(0,1,len(df.groupby(by))))
        xlimsd={}
        ylimsd={}
        xs={}
        ys={}
        cold={}
        for k,g in df.groupby(by):
            col=cs.pop()
            x=g[scatterx]
            y=g[scattery]
            xs[k]=x
            ys[k]=y
            c=colorscale.mpl_colormap(col)
            cold[k]=c
            axes.scatter(x, y, c=c, label=labeler.get(k,k), s=40, alpha=0.3);
            xlimsd[k]=axes.get_xlim()
            ylimsd[k]=axes.get_ylim()
        xlims=[min([xlimsd[k][0] for k in xlimsd.keys()]), max([xlimsd[k][1] for k in xlimsd.keys()])]
        ylims=[min([ylimsd[k][0] for k in ylimsd.keys()]), max([ylimsd[k][1] for k in ylimsd.keys()])]
        axes.set_xlim(xlims)
        axes.set_ylim(ylims)
        if setupfunc:
            axeslist=setupfunc(axes, figure)
        else:
            axeslist=[axes]
        if mfunc:
            for k in xs.keys():
                mfunc(axeslist,xs[k],ys[k],color=cold[k], mms=mms);
    axes.set_xlabel(scatterx);
    axes.set_ylabel(scattery);
    
    return axes

def make_rug(axeslist, x, y, color='b', mms=8):
    axes=axeslist[0]
    zerosx1=np.zeros(len(x))
    zerosx2=np.zeros(len(x))
    xlims=axes.get_xlim()
    ylims=axes.get_ylim()
    zerosx1.fill(ylims[1])
    zerosx2.fill(xlims[1])
    axes.plot(x, zerosx1, marker='|', color=color, ms=mms)
    axes.plot(zerosx2, y, marker='_', color=color, ms=mms)
    axes.set_xlim(xlims)
    axes.set_ylim(ylims)
    return axes

# %%
np.random.seed(42)

def rmse(p,x,y):
    yfit = np.polyval(p, x)
    return np.sqrt(np.mean((y - yfit) ** 2))

def generate_curve(x, sigma):
    return np.random.normal(10 - 1. / (x + 0.1), sigma)
x = 10 ** np.linspace(-2, 0, 8)
intrinsic_error=1.
y=generate_curve(x, intrinsic_error)
plt.scatter(x,y)

# %%
x_new=np.linspace(-0.2, 1.2, 1000)
plt.scatter(x,y, s=50)
f1=np.polyfit(x,y,1)
plt.plot(x_new,np.polyval(f1,x_new))
print "d=1, rmse=",rmse(f1,x,y)
f2=np.polyfit(x,y,2)
plt.plot(x_new,np.polyval(f2,x_new))
print "d=2, rmse=",rmse(f2,x,y)
f4=np.polyfit(x,y,4)
plt.plot(x_new,np.polyval(f4,x_new))
print "d=4, rmse=",rmse(f4,x,y)
f6=np.polyfit(x,y,6)
plt.plot(x_new,np.polyval(f6,x_new))
print "d=6, rmse=",rmse(f6,x,y)
plt.xlim(-0.2, 1.2)
plt.ylim(-1, 12)
# Out:
# d=1, rmse= 1.70524942832
# d=2, rmse= 0.89214139212
# d=4, rmse= 0.496552676012
# d=6, rmse= 0.132980700607
# (-1, 12)

# %%
#Generating a dataset
N = 200
x = np.random.random(N)
y = generate_curve(x, intrinsic_error)
plt.scatter(x, y, color=colors[0])

# %%
from sklearn.cross_validation import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, train_size=0.6)
plt.scatter(xtrain, ytrain, color=colors[1], label='Train')
plt.scatter(xtest, ytest, color=colors[0], label='Test')
plt.legend(loc='best')

# %%
ds = np.arange(21)
train_err = np.zeros(len(ds))
test_err = np.zeros(len(ds))

for i, d in enumerate(ds):
    p = np.polyfit(xtrain, ytrain, d)

    train_err[i] = rmse(p, xtrain, ytrain)
    test_err[i] = rmse(p, xtest, ytest)
# Out:
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)

# %%
fig, ax = plt.subplots()

ax.plot(ds, test_err, lw=2, label = 'test error')
ax.plot(ds, train_err, lw=2, label = 'training error')
ax.legend(loc=0)
ax.set_xlabel('degree of fit')
ax.set_ylabel('rms error')

# %%
def plot_learning_curve(d=3):
    sizes = np.linspace(2, N, 50).astype(int)
    train_err = np.zeros(sizes.shape)
    crossval_err = np.zeros(sizes.shape)

    for i, size in enumerate(sizes):
        # Train on only the first `size` points
        p = np.polyfit(xtrain[:size], ytrain[:size], d)
        
        # Validation error is on the *entire* validation set
        crossval_err[i] = rmse(p, xtest, ytest)
        
        # Training error is on only the points used for training
        train_err[i] = rmse(p, xtrain[:size], ytrain[:size])

    fig, ax = plt.subplots()
    ax.plot(sizes, crossval_err, lw=2, label='validation error')
    ax.plot(sizes, train_err, lw=2, label='training error')
    ax.plot([0, N], [intrinsic_error, intrinsic_error], '--k', label='intrinsic error')

    ax.set_xlabel('training set size')
    ax.set_ylabel('rms error')
    
    ax.legend(loc=0)
    
    ax.set_xlim(0, 99)

    ax.set_title('d = %i' % d)

# %%
plot_learning_curve(d=5)
# plt.ylim(0, 10)
# Out:
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)

# %%
plot_learning_curve(d=20)
plt.ylim(0, 10)
# Out:
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# //anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# (0, 10)

# %% [markdown]
# #k-Nearest Neighbors

# %%
df = pd.read_csv('data/lab_bias_variance_CV/olive.csv')
df.head()
# Out:
#        Unnamed: 0  region  area  palmitic  palmitoleic     ...      oleic  linoleic  linolenic  arachidic  eicosenoic
# 0  1.North-Apulia       1     1      1075           75     ...       7823       672         36         60          29
# 1  2.North-Apulia       1     1      1088           73     ...       7709       781         31         61          29
# 2  3.North-Apulia       1     1       911           54     ...       8113       549         31         63          29
# 3  4.North-Apulia       1     1       966           57     ...       7952       619         50         78          35
# 4  5.North-Apulia       1     1      1051           67     ...       7771       672         50         80          46
#
# [5 rows x 11 columns]

# %%
df.rename(columns={df.columns[0]:'areastring'}, inplace=True)
df.areastring = df.areastring.map(lambda x: x.split('.')[-1])
acidlist=['palmitic', 'palmitoleic', 'stearic', 'oleic', 'linoleic', 'linolenic', 'arachidic', 'eicosenoic']
dfsub=df[acidlist].apply(lambda x: x/100.0)
df[acidlist]=dfsub
df.head()
# Out:
#      areastring  region  area  palmitic  palmitoleic     ...      oleic  linoleic  linolenic  arachidic  eicosenoic
# 0  North-Apulia       1     1     10.75         0.75     ...      78.23      6.72       0.36       0.60        0.29
# 1  North-Apulia       1     1     10.88         0.73     ...      77.09      7.81       0.31       0.61        0.29
# 2  North-Apulia       1     1      9.11         0.54     ...      81.13      5.49       0.31       0.63        0.29
# 3  North-Apulia       1     1      9.66         0.57     ...      79.52      6.19       0.50       0.78        0.35
# 4  North-Apulia       1     1     10.51         0.67     ...      77.71      6.72       0.50       0.80        0.46
#
# [5 rows x 11 columns]

# %%
dfsouth = df[df.region==1]
dfsouthns = dfsouth[df.area != 4]
dfsouthns.head()
# Out:
#      areastring  region  area  palmitic  palmitoleic     ...      oleic  linoleic  linolenic  arachidic  eicosenoic
# 0  North-Apulia       1     1     10.75         0.75     ...      78.23      6.72       0.36       0.60        0.29
# 1  North-Apulia       1     1     10.88         0.73     ...      77.09      7.81       0.31       0.61        0.29
# 2  North-Apulia       1     1      9.11         0.54     ...      81.13      5.49       0.31       0.63        0.29
# 3  North-Apulia       1     1      9.66         0.57     ...      79.52      6.19       0.50       0.78        0.35
# 4  North-Apulia       1     1     10.51         0.67     ...      77.71      6.72       0.50       0.80        0.46
#
# [5 rows x 11 columns]

# %%
akeys=[1,2,3]
avals=['North-Apulia','Calabria','South-Apulia']
amap={e[0]:e[1] for e in zip(akeys,avals)}
ax=scatter_by(dfsouthns, 'palmitic', 'palmitoleic', by='area', labeler=amap, mfunc=make_rug, mms=20)
ax.grid(False)
ax.legend(loc='upper right');

# %%
from matplotlib.colors import ListedColormap
#cm_bright = ListedColormap(['#FF0000', '#000000','#0000FF'])
#cm = plt.cm.RdBu
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

def points_plot(X, Xtr, Xte, ytr, yte, clf, colorscale=cmap_light, cdiscrete=cmap_bold):
    h = .02
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 50),
                         np.linspace(y_min, y_max, 50))

    plt.figure()
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    plt.pcolormesh(xx, yy, Z, cmap=cmap_light, alpha=0.2)
    plt.scatter(Xtr[:, 0], Xtr[:, 1], c=ytr-1, cmap=cdiscrete, s=50, alpha=0.2,edgecolor="k")
    # and testing points
    yact=clf.predict(Xte)
    print "SCORE", clf.score(Xte, yte)
    plt.scatter(Xte[:, 0], Xte[:, 1], c=yte-1, cmap=cdiscrete, alpha=0.5, marker="s", s=35)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    return ax

# %%
from sklearn.neighbors import KNeighborsClassifier
subdf=dfsouthns[['palmitic','palmitoleic']]
subdfstd=(subdf - subdf.mean())/subdf.std()
X=subdfstd.values
y=dfsouthns['area'].values
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, train_size=0.6)
Xtr=np.concatenate((Xtrain, Xtest))

# %%
clf = KNeighborsClassifier(20, warn_on_equidistant=False).fit(Xtrain, ytrain)
points_plot(Xtr, Xtrain, Xtest, ytrain, ytest, clf)
# Out:
# SCORE 0.913043478261

# %%
clf = KNeighborsClassifier(10, warn_on_equidistant=False).fit(Xtrain, ytrain)
points_plot(Xtr, Xtrain, Xtest, ytrain, ytest, clf)
# Out:
# SCORE 0.913043478261

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8)
X_tr = np.concatenate((X_train, X_test))

# %%
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import classification_report

parameters = {"n_neighbors": np.arange(1,80,1)}
clf = KNeighborsClassifier(warn_on_equidistant=False)
gs = GridSearchCV(clf, param_grid=parameters, cv=10)
gs.fit(X_train, y_train)
y_true, y_pred = y_test, gs.predict(X_test)

print gs.best_params_, gs.best_score_
print(classification_report(y_true, y_pred))
# Out:
# {'n_neighbors': 22} 0.938864628821
#              precision    recall  f1-score   support
#
#           1       1.00      0.80      0.89         5
#           2       0.93      0.87      0.90        15
#           3       0.95      1.00      0.97        38
#
# avg / total       0.95      0.95      0.95        58

# %%
points_plot(X_tr, X_train, X_test, y_train, y_test, gs)
# Out:
# SCORE 0.948275862069
# //anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:476: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
gs.grid_scores_
# Out:
# [mean: 0.89520, std: 0.07647, params: {'n_neighbors': 1},
#  mean: 0.88646, std: 0.07681, params: {'n_neighbors': 2},
#  mean: 0.91703, std: 0.06566, params: {'n_neighbors': 3},
#  mean: 0.92140, std: 0.06919, params: {'n_neighbors': 4},
#  mean: 0.91703, std: 0.06566, params: {'n_neighbors': 5},
#  mean: 0.92140, std: 0.06397, params: {'n_neighbors': 6},
#  mean: 0.91703, std: 0.06566, params: {'n_neighbors': 7},
#  mean: 0.91703, std: 0.06547, params: {'n_neighbors': 8},
#  mean: 0.93450, std: 0.06836, params: {'n_neighbors': 9},
#  mean: 0.92576, std: 0.06803, params: {'n_neighbors': 10},
#  mean: 0.92140, std: 0.06448, params: {'n_neighbors': 11},
#  mean: 0.93013, std: 0.06813, params: {'n_neighbors': 12},
#  mean: 0.92576, std: 0.06489, params: {'n_neighbors': 13},
#  mean: 0.92576, std: 0.06489, params: {'n_neighbors': 14},
#  mean: 0.93013, std: 0.06518, params: {'n_neighbors': 15},
#  mean: 0.92576, std: 0.06489, params: {'n_neighbors': 16},
#  mean: 0.92576, std: 0.06489, params: {'n_neighbors': 17},
#  mean: 0.92576, std: 0.06489, params: {'n_neighbors': 18},
#  mean: 0.93013, std: 0.06518, params: {'n_neighbors': 19},
#  mean: 0.93013, std: 0.06518, params: {'n_neighbors': 20},
#  mean: 0.93013, std: 0.06518, params: {'n_neighbors': 21},
#  mean: 0.93013, std: 0.06518, params: {'n_neighbors': 22},
#  mean: 0.93013, std: 0.06518, params: {'n_neighbors': 23},
#  mean: 0.92576, std: 0.06489, params: {'n_neighbors': 24},
#  mean: 0.92576, std: 0.06511, params: {'n_neighbors': 25},
#  mean: 0.92576, std: 0.06489, params: {'n_neighbors': 26},
#  mean: 0.92576, std: 0.06511, params: {'n_neighbors': 27},
#  mean: 0.92576, std: 0.06489, params: {'n_neighbors': 28},
#  mean: 0.93450, std: 0.06516, params: {'n_neighbors': 29},
#  mean: 0.93013, std: 0.06518, params: {'n_neighbors': 30},
#  mean: 0.93013, std: 0.06541, params: {'n_neighbors': 31},
#  mean: 0.93013, std: 0.06541, params: {'n_neighbors': 32},
#  mean: 0.92140, std: 0.06387, params: {'n_neighbors': 33},
#  mean: 0.92140, std: 0.06387, params: {'n_neighbors': 34},
#  mean: 0.92140, std: 0.06387, params: {'n_neighbors': 35},
#  mean: 0.89083, std: 0.07366, params: {'n_neighbors': 36},
#  mean: 0.86900, std: 0.06732, params: {'n_neighbors': 37},
#  mean: 0.86026, std: 0.06058, params: {'n_neighbors': 38},
#  mean: 0.86026, std: 0.06058, params: {'n_neighbors': 39},
#  mean: 0.85590, std: 0.06188, params: {'n_neighbors': 40},
#  mean: 0.86026, std: 0.06058, params: {'n_neighbors': 41},
#  mean: 0.85590, std: 0.06188, params: {'n_neighbors': 42},
#  mean: 0.85590, std: 0.06389, params: {'n_neighbors': 43},
#  mean: 0.85590, std: 0.06188, params: {'n_neighbors': 44},
#  mean: 0.85590, std: 0.06389, params: {'n_neighbors': 45},
#  mean: 0.85153, std: 0.06188, params: {'n_neighbors': 46},
#  mean: 0.85590, std: 0.06389, params: {'n_neighbors': 47},
#  mean: 0.85590, std: 0.06188, params: {'n_neighbors': 48},
#  mean: 0.85153, std: 0.06188, params: {'n_neighbors': 49},
#  mean: 0.86026, std: 0.06058, params: {'n_neighbors': 50},
#  mean: 0.85153, std: 0.06188, params: {'n_neighbors': 51},
#  mean: 0.86026, std: 0.06058, params: {'n_neighbors': 52},
#  mean: 0.86026, std: 0.06058, params: {'n_neighbors': 53},
#  mean: 0.86026, std: 0.06058, params: {'n_neighbors': 54},
#  mean: 0.86026, std: 0.04978, params: {'n_neighbors': 55},
#  mean: 0.86463, std: 0.04903, params: {'n_neighbors': 56},
#  mean: 0.86026, std: 0.06058, params: {'n_neighbors': 57},
#  mean: 0.86463, std: 0.04903, params: {'n_neighbors': 58},
#  mean: 0.86026, std: 0.04978, params: {'n_neighbors': 59},
#  mean: 0.85590, std: 0.05017, params: {'n_neighbors': 60},
#  mean: 0.85590, std: 0.05017, params: {'n_neighbors': 61},
#  mean: 0.85590, std: 0.05017, params: {'n_neighbors': 62},
#  mean: 0.85153, std: 0.05139, params: {'n_neighbors': 63},
#  mean: 0.85590, std: 0.05017, params: {'n_neighbors': 64},
#  mean: 0.84716, std: 0.05435, params: {'n_neighbors': 65},
#  mean: 0.84716, std: 0.05435, params: {'n_neighbors': 66},
#  mean: 0.84716, std: 0.05435, params: {'n_neighbors': 67},
#  mean: 0.84716, std: 0.05435, params: {'n_neighbors': 68},
#  mean: 0.84279, std: 0.05841, params: {'n_neighbors': 69},
#  mean: 0.84279, std: 0.05841, params: {'n_neighbors': 70},
#  mean: 0.83406, std: 0.05625, params: {'n_neighbors': 71},
#  mean: 0.82533, std: 0.06181, params: {'n_neighbors': 72},
#  mean: 0.82096, std: 0.06263, params: {'n_neighbors': 73},
#  mean: 0.81223, std: 0.06868, params: {'n_neighbors': 74},
#  mean: 0.79913, std: 0.06629, params: {'n_neighbors': 75},
#  mean: 0.80349, std: 0.07563, params: {'n_neighbors': 76},
#  mean: 0.79039, std: 0.06697, params: {'n_neighbors': 77},
#  mean: 0.77293, std: 0.06724, params: {'n_neighbors': 78},
#  mean: 0.76856, std: 0.05512, params: {'n_neighbors': 79}]
