# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="white")
# plt.rc("figure", figsize=(10, 6))
np.set_printoptions(precision=4)

# %% [markdown]
# ### Loading Data

# %%
df = pd.read_csv('./data/pdt.csv')
df.head()
# Out:
#    product_id  colors  gender         activated_at     season_group  \
# 0      254010   green  Female  2014-04-11 17:44:47  Autumn / Winter
# 1      257247   brown  Female  2014-01-17 12:59:56  Autumn / Winter
# 2      259356   beige    Male  2014-01-21 16:34:25  Autumn / Winter
# 3      260398    blue  Female  2014-01-23 18:56:40  Autumn / Winter
# 4      261307  purple  Female  2014-03-04 17:28:17  Autumn / Winter
#
#             brand  original_price  special_price          sub_cat_type  \
# 0          Wardah           22112            NaN    Cleansers & Toners
# 1        Sidewalk          308449         119607     Ballerina & Flats
# 2  Noir Sur Blanc          350911         279273  Cardigans & Knitwear
# 3            Extu          151912          75012            Long Pants
# 4          Sanban          186260          89543     Leggings & Tights
#
#                   cat_type               ...                 \
# 0                   Beauty               ...
# 1                    Shoes               ...
# 2  Apparel and Accessories               ...
# 3  Apparel and Accessories               ...
# 4  Apparel and Accessories               ...
#
#    impressions_count_last_30days  net_sale_count  net_sale_count_last_7days  \
# 0                           6810             196                          5
# 1                          17780             315                          1
# 2                           4895             236                          0
# 3                           4952              55                          3
# 4                           9297             304                          1
#
#    net_sale_count_last_30days  rejected_returned_sale_count  \
# 0                          42                           133
# 1                           8                           172
# 2                          17                           197
# 3                          14                           239
# 4                          41                           135
#
#    rejected_returned_sale_count_last_7days  \
# 0                                        1
# 1                                        4
# 2                                        0
# 3                                        0
# 4                                        4
#
#    rejected_returned_sale_count_last_30days  canceled_sale_count  \
# 0                                        24                   85
# 1                                        18                   69
# 2                                        21                  242
# 3                                        17                  207
# 4                                        14                  240
#
#    canceled_sale_count_last_7days  canceled_sale_count_last_30days
# 0                               2                               27
# 1                               3                               19
# 2                               1                               19
# 3                               2                               17
# 4                               1                               21
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 0 to 3999
# Data columns (total 26 columns):
# product_id                                  4000 non-null int64
# colors                                      4000 non-null object
# gender                                      4000 non-null object
# activated_at                                4000 non-null object
# season_group                                4000 non-null object
# brand                                       4000 non-null object
# original_price                              4000 non-null float64
# special_price                               2337 non-null float64
# sub_cat_type                                4000 non-null object
# cat_type                                    4000 non-null object
# stock                                       4000 non-null int64
# views_count                                 4000 non-null int64
# views_count_last_7days                      4000 non-null int64
# views_count_last_30days                     4000 non-null int64
# impressions_count                           4000 non-null int64
# impressions_count_last_7days                4000 non-null int64
# impressions_count_last_30days               4000 non-null int64
# net_sale_count                              4000 non-null int64
# net_sale_count_last_7days                   4000 non-null int64
# net_sale_count_last_30days                  4000 non-null int64
# rejected_returned_sale_count                4000 non-null int64
# rejected_returned_sale_count_last_7days     4000 non-null int64
# rejected_returned_sale_count_last_30days    4000 non-null int64
# canceled_sale_count                         4000 non-null int64
# canceled_sale_count_last_7days              4000 non-null int64
# canceled_sale_count_last_30days             4000 non-null int64
# dtypes: float64(2), int64(17), object(7)
# memory usage: 843.8+ KB

# %%
df.describe().T[['count', 'min', 'max', 'mean', 'std']]
# Out:
#                                           count     min      max  \
# product_id                                 4000  231040   889036
# original_price                             4000   21208  5232150
# special_price                              2337   28007  4183287
# stock                                      4000       0      404
# views_count                                4000      81    36011
# views_count_last_7days                     4000       0     1190
# views_count_last_30days                    4000      14     6633
# impressions_count                          4000    3818   978349
# impressions_count_last_7days               4000       0    50240
# impressions_count_last_30days              4000     147   245490
# net_sale_count                             4000      12      583
# net_sale_count_last_7days                  4000       0       98
# net_sale_count_last_30days                 4000       1      120
# rejected_returned_sale_count               4000       3      307
# rejected_returned_sale_count_last_7days    4000       0        7
# rejected_returned_sale_count_last_30days   4000       1       35
# canceled_sale_count                        4000       7      432
# canceled_sale_count_last_7days             4000       0       34
# canceled_sale_count_last_30days            4000       1       51
#
#                                                    mean            std
# product_id                                426402.130000  189298.382144
# original_price                            308281.943500  220675.529680
# special_price                             187977.013693  153321.853450
# stock                                         24.902750      30.415852
# views_count                                 2192.609500    2104.794203
# views_count_last_7days                        63.015000      83.624686
# views_count_last_30days                      424.542000     458.211707
# impressions_count                         131360.736750  119587.456364
# impressions_count_last_7days                3892.237000    4388.049067
# impressions_count_last_30days              17577.464500   19397.242171
# net_sale_count                               177.839250      88.385114
# net_sale_count_last_7days                      3.765500       3.786502
# net_sale_count_last_30days                    21.595750      11.824119
# rejected_returned_sale_count                 160.481500      81.523602
# rejected_returned_sale_count_last_7days        1.931750       1.407511
# rejected_returned_sale_count_last_30days      16.108250       8.042525
# canceled_sale_count                          164.127000      82.888760
# canceled_sale_count_last_7days                 2.192250       1.697059
# canceled_sale_count_last_30days               16.795250       8.444504

# %%
# Dataset
print('No. of Samples:'), df.shape[0]
print('No. of Features:'), df.shape[1]

# Columns - Categorical
print('------------------')
print('No. of colors:'), df.colors.unique().shape[0]
print('No. of gender:'), df.gender.unique().shape[0]
print('No. of season_group:'), df.season_group.unique().shape[0]
print('No. of brands'), df.brand.unique().shape[0]
# Out:
# No. of Samples: 4000
# No. of Features: 26
# ------------------
# No. of colors: 114
# No. of gender: 3
# No. of season_group: 4
# No. of brands 399

# %%
# Select Columns
# print df.columns[4]
df.ix[:,:5].head()
# Out:
#    product_id  colors  gender         activated_at     season_group
# 0      254010   green  Female  2014-04-11 17:44:47  Autumn / Winter
# 1      257247   brown  Female  2014-01-17 12:59:56  Autumn / Winter
# 2      259356   beige    Male  2014-01-21 16:34:25  Autumn / Winter
# 3      260398    blue  Female  2014-01-23 18:56:40  Autumn / Winter
# 4      261307  purple  Female  2014-03-04 17:28:17  Autumn / Winter

# %% [markdown]
# ### Data Cleaning

# %%
# Price

df['special_price'] = df['special_price'] / 10000
df['original_price'] = df['original_price'] / 10000
df['disc_price'] = df['special_price']
df.loc[df['disc_price'].isnull(), 'disc_price'] = df['original_price']

df[['original_price', 'special_price', 'disc_price']].head()
# Out:
#    original_price  special_price  disc_price
# 0          2.2112            NaN      2.2112
# 1         30.8449        11.9607     11.9607
# 2         35.0911        27.9273     27.9273
# 3         15.1912         7.5012      7.5012
# 4         18.6260         8.9543      8.9543

# %% [markdown]
# ### Exploratory Data Analysis

# %%
f, ax = plt.subplots(figsize=(9, 9))
sns.corrplot(df, ax=ax, cmap="PuRd", diag_names=False, sig_stars=False);

# %%
data = df[['net_sale_count', 'views_count', 'impressions_count', 'gender']]

sns.pairplot(data, hue='gender', size=2.5);

# %%
sns.factorplot("gender", data=df, palette="Blues");

# %%
sns.factorplot("season_group", data=df, hue='gender', palette="Blues");

# %%
sns.factorplot("colors", data=df , palette="PuBu_d");

# %%
df.colors[:10].sort(ascending=0).plot(kind='barh')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-465-48ad30b3ea21> in <module>()
# ----> 1 df.colors[:10].sort(ascending=0).plot(kind='barh')
#
# AttributeError: 'NoneType' object has no attribute 'plot'

# %%
top_colors = df.colors.value_counts()
top_colors[:10].plot(kind='barh')
plt.xlabel('No. of Products');

# %%
fg = sns.FacetGrid(df, hue="gender", aspect=3, palette="Set1")
fg.map(sns.kdeplot, "stock", shade=True)
fg.set(xlim=(0, 80))
plt.legend(loc="best");

# %%
fg = sns.FacetGrid(df, hue="season_group", aspect=3, palette="Set1")
fg.map(sns.kdeplot, "stock", shade=True)
fg.set(xlim=(0, 80))
plt.legend(loc="best");

# %%
fg = sns.FacetGrid(df, hue="gender", aspect=3, palette="Set1")
fg.map(sns.kdeplot, "disc_price", shade=True)
fg.set(xlim=(0, 80))
plt.legend(loc="best");

# %%
fg = sns.FacetGrid(df, hue="season_group", aspect=3, palette="Set1")
fg.map(sns.kdeplot, "disc_price", shade=True)
fg.set(xlim=(0, 80))
plt.legend(loc="best");

# %%
g = sns.lmplot("disc_price","stock", df, col='gender',
           hue='gender', palette="Set1", fit_reg=False)

g.set(xlim=(0, 200), ylim=(0, 300));

# %%
g = sns.lmplot("disc_price","stock", df, col='season_group', hue='season_group',
               palette="Set1", fit_reg=False)

g.set(xlim=(0, 200), ylim=(0, 300));

# %%
g = sns.jointplot("views_count", "net_sale_count", df,
                  kind="hex", color="dodgerblue", xlim=(0,6000), ylim=(0,400))

# %%
g = sns.jointplot("impressions_count", "net_sale_count", df,
                  kind="hex", color="#8855AA", xlim=(0,500000), ylim=(0,400))

# %%
fg = sns.lmplot("views_count", "net_sale_count", df,
                col='gender', hue='gender', 
                palette="Set1", scatter_kws={"alpha": .1},
                fit_reg=True).set(xlim=(0, 10000), ylim=(0,400));

fg.despine(left=True);

# %%
fg = sns.lmplot("impressions_count", "net_sale_count", df,
                col='gender', hue='gender', 
                palette="Set1", scatter_kws={"alpha": .1},
                fit_reg=True).set(xlim=(0, 1000000), ylim=(0,400));

fg.despine(left=True);

# %%
sns.factorplot("gender", "disc_price", data=df, palette="BuPu_d");

# %%
sns.violinplot(df["disc_price"], df["gender"], color="BuPu_d").set_ylim(0, 100)
sns.despine(left=True);

# %%
sns.factorplot("season_group", "stock", data=df, palette="BuPu_d");

# %%
fg = sns.FacetGrid(df, hue="gender", aspect=3, palette="Set1")
fg.map(sns.kdeplot, "net_sale_count", shade=True)
fg.set(xlim=(0, 80))
plt.legend(loc="best")

fg = sns.FacetGrid(df, hue="gender", aspect=3, palette="Set1")
fg.map(sns.kdeplot, "net_sale_count_last_30days", shade=True)
fg.set(xlim=(0, 80))
plt.legend(loc="best")

fg = sns.FacetGrid(df, hue="gender", aspect=3, palette="Set1")
fg.map(sns.kdeplot, "net_sale_count_last_7days", shade=True)
fg.set(xlim=(0, 80))
plt.legend(loc="best");

# %% [markdown]
# ### Feature Engineering

# %%
# Discount Price

df['disc_pct'] = (1 - (df['disc_price']/df['original_price'])) * 100

# Calculate number of days products have launched

from datetime import datetime
now = datetime.now()

df['activated_at'] = pd.to_datetime(df['activated_at'])
df['days_launch'] = (now - df.activated_at).astype('timedelta64[D]')

# Comparing sales and impression relationships

df['sale_imp_30'] = (df.net_sale_count_last_30days - df.net_sale_count_last_7days) / (df.impressions_count_last_30days - df.impressions_count_last_7days) * 100
df['sale_imp_total'] = (df.net_sale_count - df.net_sale_count_last_7days) / (df.impressions_count - df.impressions_count_last_7days) * 100

new_features = ['disc_pct', 'days_launch', 'sale_imp_30', 'sale_imp_total']
df[new_features].describe()
# Out:
#           disc_pct  days_launch  sale_imp_30  sale_imp_total
# count  4000.000000  4000.000000  4000.000000     4000.000000
# mean     23.090448   239.230750     0.468506        0.291976
# std      22.816632    65.977873     4.650182        0.463009
# min       0.000000   108.000000     0.003561        0.004171
# 25%       0.000000   192.000000     0.081694        0.079691
# 50%      21.264738   226.000000     0.165680        0.163445
# 75%      45.726018   291.000000     0.338456        0.334879
# max      80.659882   382.000000   244.444444       13.263708

# %%
# Downsize to few features

features = ['colors', 'gender', 'season_group', 'brand', 'original_price',
            'disc_price', 'disc_pct', 'days_launch', 'sale_imp_30', 'sale_imp_total']
target = ['net_sale_count_last_7days']

df_clean = df[features]
print df_clean.shape
df_clean.head()
# Out:
# (4000, 10)
#    colors  gender     season_group           brand  original_price  \
# 0   green  Female  Autumn / Winter          Wardah          2.2112
# 1   brown  Female  Autumn / Winter        Sidewalk         30.8449
# 2   beige    Male  Autumn / Winter  Noir Sur Blanc         35.0911
# 3    blue  Female  Autumn / Winter            Extu         15.1912
# 4  purple  Female  Autumn / Winter          Sanban         18.6260
#
#    disc_price   disc_pct  days_launch  sale_imp_30  sale_imp_total
# 0      2.2112   0.000000          283     0.644712        0.492471
# 1     11.9607  61.223087          367     0.047922        0.141902
# 2     27.9273  20.414863          363     0.439390        0.268698
# 3      7.5012  50.621412          361     0.394124        0.152292
# 4      8.9543  51.925803          321     0.506329        0.846842

# %%
plt.hist(df.disc_pct, color=sns.desaturate("indianred", .75))
sns.despine(left=True);

# %%
sns.lmplot("disc_pct", "net_sale_count", df,
           palette="BuPu_d", fit_reg=True).set(xlim=(0, 80), ylim=(0,400));

# %%
sns.lmplot("disc_pct", "net_sale_count", df,
           col='gender', hue='gender',
           palette="Set2", fit_reg=True).set(xlim=(0, 80), ylim=(0,400));

# %% [markdown]
# ### Splitting into Training and Test Test

# %%
df_clean.head()
# Out:
#    colors  gender     season_group           brand  original_price  \
# 0   green  Female  Autumn / Winter          Wardah          2.2112
# 1   brown  Female  Autumn / Winter        Sidewalk         30.8449
# 2   beige    Male  Autumn / Winter  Noir Sur Blanc         35.0911
# 3    blue  Female  Autumn / Winter            Extu         15.1912
# 4  purple  Female  Autumn / Winter          Sanban         18.6260
#
#    disc_price   disc_pct  days_launch  sale_imp_30  sale_imp_total
# 0      2.2112   0.000000          283     0.644712        0.492471
# 1     11.9607  61.223087          367     0.047922        0.141902
# 2     27.9273  20.414863          363     0.439390        0.268698
# 3      7.5012  50.621412          361     0.394124        0.152292
# 4      8.9543  51.925803          321     0.506329        0.846842
