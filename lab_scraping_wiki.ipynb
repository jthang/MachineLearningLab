# %%
# %matplotlib inline

from collections import defaultdict
import pandas as pd
import matplotlib as plt
import requests
from bs4 import BeautifulSoup
from pattern import web

# %%
def get_countries_population(tables):
    result = defaultdict(dict)
    
    #Extract data for a single table
    for tbl in tables:
        headers = tbl('tr')
        first_header = headers[0]
        th_s = first_header('th')
        
        years = [int(val.content) for val in th_s if val.content.isnumeric()]
        year_indices = [idx for idx, val in enumerate(th_s) if val.content.isnumeric()]
        print years
        print year_indices
        
        #iterate over the tables, extract headings and data into a dict
        rows = tbl('tr')[1:] #first row is header
        for row in rows:
            tds = row('td')
            country_name = tds[1]('a')[0].content
            population_by_year = [int(tds[colidx].content.replace(',',''))
                                  for colidx in year_indices]
            subdict = dict(zip(years, population_by_year))
            result[country_name].update(subdict)
        return result
        
result = get_countries_population(tables_by_type[u'Country or territory'])
print len(result), "Countries extracted"
print result[u'Canada']

# %%
url = 'http://en.wikipedia.org/wiki/List_of_countries_by_past_and_future_population'
pop_resp = requests.get(url)

soup = BeautifulSoup(pop_resp.content)

# %%
population_tables = []
for table in soup.find_all('table', {'class': ['sortable', 'wikitable']}):
    if 'sortable' in table.attrs.get('class') and 'wikitable' in table.attrs.get('class'):
        if table.find('th').text == 'Country or territory':
            population_tables.append(table)

# %%
def get_table_data(table):
    column_names = []
    col_indexes = []
    table_head = table.find_all('th')
    for idx, col_name in enumerate(table_head):
        if col_name.text != '%':
            col_indexes.append(idx)
            column_names.append(col_name.text)
    print(column_names)
    
    rows_data = []
    table_row = table.find_all('tr')
    for idx, row_td in enumerate(table_row):
        row = []
        for col_idx, col_val in enumerate(row_td.find_all('td')):
            if col_idx in col_indexes:
                if col_idx == 0:
                    row.append(col_val.text[1:])
                else:
                    row.append(int(col_val.text.replace(',', '')))
        if row:
            rows_data.append(row)
    return column_names, rows_data

# %%
def get_population_df(population_tables):
    population_df = None
    for table in population_tables:
        columns, rows = get_table_data(table)
        table_df = pd.DataFrame(rows, columns=columns)
        table_df = table_df.set_index(['Country or territory'])
        if population_df is None:
            population_df = table_df
        else:
            population_df = population_df.join(table_df, how='outer')
    return population_df

# %%
population_df = get_population_df(population_tables)
population_df.head()

# %% [markdown]
# #Singapore Economic History

# %%
def extract(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text)
#     table = soup.find('span', {"id": "Economic_history"}).findNext('table', {"class": "wikitable"})
    table = soup.find('table', {"class": "wikitable"})
    
    economy = list()
    for row in table.find_all('tr'):
        cells = row.find_all('td')
        if len(cells) == 5:
            year = cells[0].string
            gdp = cells[1].string
            usd = cells[2].string
            nominal = cells[3].string
            ppp = cells[4].string
            economy.append({'year':year, 
                         'gdp':gdp,
                         'usd':usd,
                         'nominal':nominal})
        else: pass
    return pd.DataFrame(economy)
        
df = extract("http://en.wikipedia.org/wiki/Economy_of_Singapore")
indexed_df = df.set_index(['year'])
indexed_df
# Out:
#           gdp nominal                     usd
# year
# 1980   25,117   39.65  2.14 Singapore Dollars
# 1985   39,036   36.63  2.20 Singapore Dollars
# 1990   66,778   52.09  1.81 Singapore Dollars
# 1995  119,470   86.14  1.41 Singapore Dollars
# 2000  159,840   66.19  1.72 Singapore Dollars
# 2005  194,360   67.54  1.64 Singapore Dollars
# 2007  224,412   74.61  1.42 Singapore Dollars
# 2008  235,632   73.71  1.37 Singapore Dollars
# 2009  268,900   78.53  1.50 Singapore Dollars
# 2010  309,400   82.13  1.32 Singapore Dollars
# 2011  270,020       –  1.29 Singapore Dollars
# 2013        –       –  1.25 Singapore Dollars

# %% [markdown]
# #International Trade Agreements

# %%
def trade(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text)
#     table = soup.find('span', {"id": "Economic_history"}).findNext('table', {"class": "wikitable"})
    table = soup.find('table', {"class": "wikitable sortable"})
    
    int_trade = list()
    for row in table.find_all('tr'):
        cells = row.find_all('td')
        if len(cells) == 7:
            economy = cells[0].string
            agreement = cells[1].string
            concluded = cells[3].string
            signed = cells[4].string
            effective = cells[5].string
            int_trade.append({'economy':economy, 
                              'agreement':agreement,
                              'concluded':concluded,
                              'effective':effective})
        else: pass
    return pd.DataFrame(int_trade)
        
df = trade("http://en.wikipedia.org/wiki/Economy_of_Singapore")
indexed_df = df.set_index(['economy'])
indexed_df
# Out:
#                                                                          agreement  \
# economy
# New Zealand                      Agreement between New Zealand and Singapore on...
# European Free Trade Association    Agreement between the EFTA States and Singapore
# United States                         United States-Singapore Free Trade Agreement
# Jordan                                       Singapore Jordan Free Trade Agreement
# Brunei                           Trans-Pacific Strategic Economic Partnership A...
# India                            India – Singapore Comprehensive Economic Coope...
# Korea                                         Korea-Singapore Free Trade Agreement
# Peru                                           Peru-Singapore Free Trade Agreement
#
#                                         concluded       effective
# economy
# New Zealand                        18 August 2000  1 January 2001
# European Free Trade Association     11 April 2002  1 January 2003
# United States                    19 November 2002  1 January 2004
# Jordan                              29 April 2004
# Brunei                                             1 January 2006
# India                               November 2004   1 August 2005
# Korea                            28 November 2004        End 2005
# Peru                               September 2007      Early 2009

# %% [markdown]
# #Chicago reader

# %%
from bs4 import BeautifulSoup
from urllib2 import urlopen
from time import sleep

r = requests.get('http://www.chicagoreader.com/chicago/best-of-chicago-2011-food-drink/BestOf?oid=4106228')
soup = BeautifulSoup(r.text)

links_section = soup.find(name='dl', attrs={'class':'boccat'})
link_rows = links_section.find_all(name='dd')

category_links = ["http://www.chicagoreader.com" + row.a['href'] for row in link_rows]

def get_category_winners(category_link):
    r = requests.get(category_link)
    soup = make_soup(category_link)
    return {"category": soup.find("h1", "headline").string,
            "url": category_link,
            "winner": [h2.string for h2 in soup.findAll("h2", "boc1")],
            "runners_up": [h2.string for h2 in soup.findAll("h2", "boc2")]
            }

# %%
get_category_winners(category_links[0])
# Out:
# {'category': u"Best restaurant that's been around forever and is still worth the trip\xa0",
#  'runners_up': [u'Frontera Grill',
#   u'Chicago Diner  ',
#   u'Sabatino\u2019s',
#   u'Twin Anchors'],
#  'url': 'http://www.chicagoreader.com/chicago/BestOf?category=1979894&year=2011',
#  'winner': [u'Lula Cafe']}

# %%
data = []
for category_link in category_links[0:5]:
    winner = get_category_winners(category_link)
    data.append(winner)
    sleep(1)
print data
# Out:
# [{'category': u"Best restaurant that's been around forever and is still worth the trip\xa0", 'url': 'http://www.chicagoreader.com/chicago/BestOf?category=1979894&year=2011', 'winner': [u'Lula Cafe'], 'runners_up': [u'Frontera Grill', u'Chicago Diner  ', u'Sabatino\u2019s', u'Twin Anchors']}, {'category': u'Best fancy restaurant in Chicago\xa0', 'url': 'http://www.chicagoreader.com/chicago/best-fancy-restaurant-in-chicago/BestOf?oid=4088017', 'winner': [u'Alinea '], 'runners_up': [u'Blackbird', u'Girl & the Goat', u'Green Zebra', u'The Publican']}, {'category': u'Best bang for your buck\xa0', 'url': 'http://www.chicagoreader.com/chicago/best-bang-for-your-buck/BestOf?oid=4088018', 'winner': [u'Big Star', u'Sultan\u2019s Market'], 'runners_up': [u'Frasca Pizzeria & Wine Bar', u'Chutney Joe\u2019s', u'"My boyfriend!"']}, {'category': u'Best chef\xa0', 'url': 'http://www.chicagoreader.com/chicago/best-chef/BestOf?oid=4088191', 'winner': [u'Rick Bayless (Frontera Grill, Topolobampo, Xoco)'], 'runners_up': [u'Grant Achatz (Alinea, Next, The Aviary)', u'Stephanie Izard (Girl & the Goat)']}, {'category': u'Best up-and-coming chef\xa0', 'url': 'http://www.chicagoreader.com/chicago/best-up-and-coming-chef/BestOf?oid=4088225', 'winner': [u'Jeremy Kiens, \nDunlays on Clark'], 'runners_up': [u'Jimmy Bannos Jr., The Purple Pig', u'Cesar Pineda, Ciao Amore Ristorante', u'Rodney Staton, Bite Cafe']}]

# %% [markdown]
# #Wiki Table

# %%
def extract(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text)
    table = soup.find('table', {"class": "wikitable"})
        
    for row in table.find_all('tr'):
        cells = row.find_all('td')
        if len(cells) == 8:
            fr = cells[0].string
            province = cells[4].string
            print fr, province
        else: pass
        
extract ("https://fr.wikipedia.org/wiki/Liste_des_communes_de_la_R%C3%A9gion_wallonne")
# Out:
# Aiseau-Presles 22,19
# Amay 27,61
# Amblève 125,15
# Andenne 86,17
# Anderlues 17,02
# Anhée 65,67
# Ans 23,35
# Anthisnes 37,08
# Antoing 31,13
# Arlon 118,64
# Assesse 78,16
# Ath 126,95
# Attert 70,94
# Aubange 45,6
# Aubel 18,83
# Awans 27,16
# Aywaille 79,97
# Baelen 85,73
# Bassenge 38,17
# Bastogne 172,03
# Beaumont 92,97
# Beauraing 174,55
# Beauvechain 38,58
# Belœil 61,55
# Berloz 14,49
# Bernissart 43,42
# Bertogne 91,67
# Bertrix 137,7
# Beyne-Heusay 7,32
# Bièvre 109,59
# Binche 60,66
# Blegny 26,07
# Les Bons Villers 42,55
# Bouillon 149,09
# Boussu 20,01
# Braine-l'Alleud 52,12
# Braine-le-Château 22,7
# Braine-le-Comte 84,68
# Braives 44
# Brugelette 28,4
# Brunehaut 46,11
# La Bruyère 52,98
# Bullange 150,49
# Burdinne 32,57
# Burg-Reuland 108,96
# Butgenbach 97,31
# Celles 67,14
# Cerfontaine 83,45
# Chapelle-lez-Herlaimont 18,1
# Charleroi 102,08
# Chastre 31,27
# Châtelet 27,03
# Chaudfontaine 25,52
# Chaumont-Gistoux 48,09
# Chièvres 46,91
